# %% [markdown]
# <a href="https://colab.research.google.com/github/naiksahana/SQL-MurderMystery/blob/main/SQLMurderMystery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3 as sql

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
conn = sql.connect('/content/drive/My Drive/sql-murder-mystery.db')

# %%
import pandas as pd

# %%
conn

# %%
query="""
SELECT *
FROM crime_scene_report
WHERE city="SQL City" AND date='20180115' AND type='murder'
ORDER BY date;
"""
#pd.read_sql_query(query,conn)

# %%
pd.read_sql_query(query,conn)
# Out:
#        date    type                                        description  \
# 0  20180115  murder  Security footage shows that there were 2 witne...
#
#        city
# 0  SQL City

# %%
query1="""
SELECT *
FROM person
where address_street_name="Northwestern Dr" Order by address_number
;
"""

# %%
pd.read_sql_query(query1,conn)
# Out:
#        id                  name  license_id  address_number  \
# 0   89906       Kinsey Erickson      510019             309
# 1   15171          Weldon Penso      336999             311
# 2   40336       Fredia Billeter      251082             404
# 3   85280             Donn Duin      569122             540
# 4   12711        Norman Apolito      667757             599
# 5   75484          Del Tacderen      447887             607
# 6   26758      Angelena Billman      942074             629
# 7   39688            Abe Roeker      537445             689
# 8   10010             Muoi Cary      385336             741
# 9   40760          Renata Faver      976650             745
# 10  25615         Olevia Morena      388477             812
# 11  99826          Ivy Kazarian      994470             892
# 12  44542        Ivory Mcgrevey      873842             897
# 13  55130        Shiloh Huntoon      472118             951
# 14  33415         Homer Simpson      108392             981
# ...

# %%
query2="""
SELECT *
FROM person
where name like 'Annabel%' and address_street_name="Franklin Ave"
;
"""

# %%
pd.read_sql_query(query2,conn)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %%
query3="""
SELECT *
FROM interview
where person_id='14887'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
query3="""
SELECT *
FROM interview
where person_id='16371'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#    person_id                                         transcript
# 0      16371  I saw the murder happen, and I recognized the ...

# %%
query3="""
SELECT *
FROM get_fit_now_check_in
where membership_id like '48Z%' and check_in_date='20180109'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %%
query3="""
SELECT *
FROM get_fit_now_member
where id='48Z7A'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#       id  person_id          name  membership_start_date membership_status
# 0  48Z7A      28819  Joe Germuska               20160305              gold

# %%
query3="""
SELECT *
FROM get_fit_now_member
where id='48Z55'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
query3="""
SELECT *
FROM person
where id='28819'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#       id          name  license_id  address_number address_street_name  \
# 0  28819  Joe Germuska      173289             111             Fisk Rd
#
#          ssn
# 0  138909730

# %%
query3="""
SELECT *
FROM person
where id='67318'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  871539279

# %%
query3="""
SELECT *
FROM drivers_license
where id='173289'
;
"""
pd.read_sql_query(query3,conn)
# Out:
# Empty DataFrame
# Columns: [id, age, height, eye_color, hair_color, gender, plate_number, car_make, car_model]
# Index: []

# %%
query3="""
SELECT *
FROM drivers_license
where id='423327'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#   car_model
# 0  Spark LS

# %% [markdown]
# **Jeremy Bowers** is the murderer

# %%
query3="""
SELECT *
FROM drivers_license
where hair_color='red' and gender='female' and car_make='Tesla'and car_model='Model S'
;
"""
pd.read_sql_query(query3,conn)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %%
query3="""
SELECT *
FROM person
where license_id IN(202298,291182,918773)
;
"""
pd.read_sql_query(query3,conn)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  78881          Red Korb      918773             107         Camerata Dr
# 1  90700     Regina George      291182             332           Maple Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  961388910
# 1  337169072
# 2  987756388

# %%
query3="""
SELECT *
FROM facebook_event_checkin
where person_id IN(78881,90700,99716)
;
"""
pd.read_sql_query(query3,conn)
# Out:
#    person_id  event_id            event_name      date
# 0      99716      1143  SQL Symphony Concert  20171206
# 1      99716      1143  SQL Symphony Concert  20171212
# 2      99716      1143  SQL Symphony Concert  20171229

# %% [markdown]
# **Miranda Priestly**	is the one who had given a deal to murderer
